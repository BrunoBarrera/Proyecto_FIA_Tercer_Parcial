# %% [markdown]
# # Creacion del dataset
# En esta sección, adaptaremos los datos sin limpiar a un formato que podamos manipular a lo largo del proceso

# %%
import pandas as pd
import pickle
import os

# %%
path = "dataset"
classifications = ['athletics','cricket','football','rugby','tennis']
df = pd.DataFrame(columns=['file_name','content','category'])
content = []
classificationCol = []
categoryID = []
filename = []
for classification in classifications:
    for root, dirs, files in os.walk(os.path.join(path, '{}'.format(classification)), topdown=False):
        for name in files:
            filePath = os.path.join(root, name)
            fileContent = open(filePath,mode='r').read()
            content.append(fileContent)
            classificationCol.append(classification)
            categoryID.append(classifications.index(classification) )
            filename.append(name)

df["content"] = content
df["category"] = classificationCol
df["file_name"] = filename
df
# Out:
#     file_name                                            content   category
# 0     001.txt  Claxton hunting first major medal\n\nBritish h...  athletics
# 1     002.txt  O'Sullivan could run in Worlds\n\nSonia O'Sull...  athletics
# 2     003.txt  Greene sets sights on world title\n\nMaurice G...  athletics
# 3     004.txt  IAAF launches fight against drugs\n\nThe IAAF ...  athletics
# 4     005.txt  Dibaba breaks 5,000m world record\n\nEthiopia'...  athletics
# ..        ...                                                ...        ...
# 732   096.txt  Agassi into second round in Dubai\n\nFourth se...     tennis
# 733   097.txt  Mauresmo fights back to win title\n\nWorld num...     tennis
# 734   098.txt  Federer wins title in Rotterdam\n\nWorld numbe...     tennis
# 735   099.txt  GB players warned over security\n\nBritain's D...     tennis
# 736   100.txt  Sharapova overcomes tough Molik\n\nWimbledon c...     tennis
#
# [737 rows x 3 columns]

# %%
# Exportamos
with open('dataframes/dirty_data.pickle', 'wb') as output:
    pickle.dump(df, output)
with open('dataframes/labels.pickle', 'wb') as output:
    pickle.dump(categoryID, output)
